# %% [markdown]
# # NEU-DET exploratory data analysis
# This notebook reads the aggregate, image-free report committed under `reports/metrics/published/data`. Re-run `idi-prepare` to regenerate it. Keep notebook outputs cleared before committing.

# %%
import json
from pathlib import Path

metadata_path = Path('../reports/metrics/published/data/dataset_summary.json')
metadata = json.loads(metadata_path.read_text(encoding='utf-8'))
metadata['source_statistics'], metadata['splits'], metadata['warnings']
