# %% [markdown]
# # NEU-DET exploratory data analysis
# Run `idi-prepare` first. Treat `data/processed/neu_det/metadata.json` as the source of truth for counts and box statistics. Keep notebook outputs cleared before committing.

# %%
import json
from pathlib import Path

metadata_path = Path('../data/processed/neu_det/metadata.json')
metadata = json.loads(metadata_path.read_text(encoding='utf-8'))
metadata['source_statistics']
