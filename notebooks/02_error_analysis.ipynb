# %% [markdown]
# # Detection error analysis
# Analyze the committed aggregate test report without changing the frozen result. Raw FP/FN images and the detailed local manifest remain under `artifacts/evaluations/test/error_samples` because the dataset license is unclear.

# %%
import json
from pathlib import Path

report_path = Path('../reports/metrics/published/experiment/experiment_summary.json')
report = json.loads(report_path.read_text(encoding='utf-8'))
report['test']['summary'], report['test']['per_class'], report['test']['error_analysis']
