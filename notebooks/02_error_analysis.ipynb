# %% [markdown]
# # Detection error analysis
# Run `idi-evaluate` first. This notebook is intentionally lightweight: analyze the generated evaluation JSON and review `error_samples/false_positives` and `error_samples/false_negatives` without changing the frozen test result.

# %%
import json
from pathlib import Path

report_path = Path('../reports/metrics/test/evaluation.json')
report = json.loads(report_path.read_text(encoding='utf-8'))
report['metrics'], report['error_analysis'], report['latency']
